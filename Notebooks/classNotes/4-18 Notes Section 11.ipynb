# %% [markdown]
# # Class Notes
#
# Below is a copy of live-coded notes from class Thursday April 18. You can study what we worked on, recreate your own version, or copy them directly into Thonny to re-run the code.
#
# In today's class we mainly focused on looking at details for Project 1, and began the conceptual parts for the topic of Objects and Classes (chapter 16)

# %% [markdown]
# **Code run in the Python Shell**
#
# In addition to the brief examples below, we reviewed the overall structure of Project 1, which is posted on Canvas (the diagram of functions used will be posted as well).
#
# ```Python
# Python 3.7.2 (bundled)
# >>> #Looking at tuples returned from functions
# >>> def city_state():
#     city = input("What city are you in?")
#     state = input("And which state is that in?")
#     return city, state
#
# >>> #So what type does it return?
# >>> result = city_state()
# What city are you in?Newark
# And which state is that in?Delaware
# >>> result
# ('Newark', 'Delaware')
# >>> type(result)
# <class 'tuple'>
# >>> #how do we unpack those values automatically?
# >>> current_city, current_state = city_state()
# What city are you in?Las Vegas
# And which state is that in?Confusion
# >>> print(current_city)
# Las Vegas
# >>> print(current_state)
# Confusion
# >>> city, state, county = city_state()
# What city are you in?London
# And which state is that in?England
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# ValueError: not enough values to unpack (expected 3, got 2)
# >>> # unpacking too few or too many values creates an error -- check the return and assignment statements
# >>> result
# ('Newark', 'Delaware')
# >>> len(result)
# 2
# >>> result[1]
# 'Delaware'
# #Important detail about Tuples: We're not allowed to modify them
# # Which means this isn't allowed:
# >>> result[1] = "Pennsylvania"
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# TypeError: 'tuple' object does not support item assignment
# # And neither is this:
# >>> result.append("New Castle County")
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# AttributeError: 'tuple' object has no attribute 'append'
# >>> my_quintuple = (2,3,5,7,11)
# >>> len(my_quintuple)
# 5
# >>> first, second, third, fourth, fifth = my_quintuple
# >>> first
# 2
# >>> third
# 5
# >>> fifth
# 11
# >>> result.remove("Delaware")
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# AttributeError: 'tuple' object has no attribute 'remove'
# >>> del result[0]
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# TypeError: 'tuple' object doesn't support item deletion
# >>> #can we convert its type? only to something compatible
# >>> list(result)
# ['Newark', 'Delaware']
# >>> type(result)
# <class 'tuple'>
# >>> result_as_list = list(result)
# >>> result_as_list
# ['Newark', 'Delaware']
# >>> result_as_list[1] = "New Jersey"
# >>> result_as_list
# ['Newark', 'New Jersey']
# >>> result
# ('Newark', 'Delaware')
# >>> #what about to a non-compatible type?
# >>> int(result)
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'tuple'
# >>> str(result)
# "('Newark', 'Delaware')"
# >>> #The str function is compatible with just about everything. Eg:
# >>> str(city_state)
# '<function city_state at 0x03205300>'
# >>> #speaking of conversion functions, what if we convert a list to a list:
# >>> list()
# []
# >>> list("hello")
# ['h', 'e', 'l', 'l', 'o']
# >>> hello1 = list("hello")
# >>> hello1
# ['h', 'e', 'l', 'l', 'o']
# >>> hello2 = list(hello1)
# >>> hello2
# ['h', 'e', 'l', 'l', 'o']
# >>> #are they the same list?
# >>> hello2 is hello1
# False
# >>> #Nope!
# >>> hello1.append("!")
# >>> hello1
# ['h', 'e', 'l', 'l', 'o', '!']
# >>> hello2
# ['h', 'e', 'l', 'l', 'o']
# >>> #Are their elements the same?
# >>> hello1[0] is hello2[0]
# True
# >>> "h" is hello1[0]
# True
# >>> #how do we create a tuple?
# >>> (1,2,3)
# (1, 2, 3)
# >>> tuple(hello1)
# ('h', 'e', 'l', 'l', 'o', '!')
# >>> #do we have matplotlib installed?
# >>> import matplotlib
# >>> import matplotlib.pyplot as plt
# >>> plt.plot([1, 2, 3, 4])
# [<matplotlib.lines.Line2D object at 0x0EC99D70>]
# >>> plt.ylabel('some numbers')
# Text(0, 0.5, 'some numbers')
# >>> plt.show()
#
# >>> plt.plot([1,2,3,4,5,4,3,2,1])
# [<matplotlib.lines.Line2D object at 0x0EE354B0>]
# >>> plt.show()
# >>>
#
# ```
