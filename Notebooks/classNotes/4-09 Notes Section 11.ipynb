# %% [markdown]
# # Class Notes
#
# Below is a copy of live-coded notes from class Tuesday April 9. You can study what we worked on, recreate your own version, or copy them directly into Thonny to re-run the code.

# %% [markdown]
# **Code run in the Python Shell**
# *note: Some of this code relies on the* `*.py` *files listed above*
#
# ```Python
# >>> a_string = "hello"
# >>> a_string.capitalize()
# 'Hello'
# >>> a_string
# 'hello'
# >>> a_string.upper()
# 'HELLO'
# >>> super_strong_password = "1234Dinosaur"
# >>> lc_password = super_string_password.lower()
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# NameError: name 'super_string_password' is not defined
# >>> lc_password = super_strong_password.lower()
# >>> lc_password
# '1234dinosaur'
# >>> split_password = lc_password.split("4")
# >>> split_password
# ['123', 'dinosaur']
# >>> sentences = "We are learning about strings. The weather is great today. Let's finish up and go have lunch outside."
# >>> sentences.split()
# ['We', 'are', 'learning', 'about', 'strings.', 'The', 'weather', 'is', 'great', 'today.', "Let's", 'finish', 'up', 'and', 'go', 'have', 'lunch', 'outside.']
# >>> sentences.split(".")
# ['We are learning about strings', ' The weather is great today', " Let's finish up and go have lunch outside", '']
# >>> sentence_list = []
# >>> for sentence in sentences.split("."):
#     sentence_list.append(sentence.strip())
#
# >>> sentence_list
# ['We are learning about strings', 'The weather is great today', "Let's finish up and go have lunch outside", '']
# >>> "Text with \'quotes\' and \"double quotes\""
# 'Text with \'quotes\' and "double quotes"'
# >>> "Text with \'quotes\' "
# "Text with 'quotes' "
# >>> str1 = "Text with \'quotes\' "
# >>> str2 = "Text with 'quotes' "
# >>> len(str1)
# 19
# >>> len(str2)
# 19
# >>> str1 == str2
# True
# >>> str1 is str2
# False
# >>> str1.startswith(str2)
# True
# >>> str1.startswith(str2[:4])
# True
# >>> sentence_list[0].find('in')
# 12
# >>> sentence_list[0][12:]
# 'ing about strings'
# >>> sentence_list[0].find('in', 13)
# 25
# >>> for sentence in sentence_list:
#     substr_index = sentence.find("in")
#     print(sentence[:substr_index])
#
# We are learn
# The weather is great toda
# Let's f
#
# >>> #Whoops! What happened with that second one? Let's look at the whole string:
# >>> sentence_list[1]
# 'The weather is great today'
# >>> #Hmmm... and what does `find('in')` return...
# >>> sentence_list[1].find('in')
# -1
# >>> #Ah-hah! It returns `-1` to signal that it couldn't find the value we're looking for. We need to account for that:
# >>> for sentence in sentence_list:
#     substr_index = sentence.find("in")
#     if substr_index == -1:
#         print("Not found")
#     else:
#         print(sentence[:substr_index+2])
#
# We are learnin
# Not found
# Let's fin
# Not found
# >>> "....".split('.')
# ['', '', '', '', '']
# >>> #strings are immutable
# >>> some_string = "This string has no topys" #Whoops, Looks like it actually does have a typo
# >>> some_string[-2] = 'o' #Can we fix one of the typos in the string above?
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# TypeError: 'str' object does not support item assignment
# >>> #Nope, strings can't be changed, but there is a way to fix it:
# >>> fixed_string = some_string.replace("topy", "typo") #this finds the first argument, and replaces it with the second, returning the result
# >>> print(fixed_string)
# This string has no typos
# >>> for sentence in sentence_list:
#     substr_index = sentence.find("in")
#     if substr_index == -1:
#         print("Not found")
#     elif len(sentence) > 0:
#         print(sentence[:substr_index])
#
# We are learn
# Not found
# Let's f
# Not found
# >>> for sentence in sentence_list:
#     substr_index = sentence.find("in")
#     if substr_index == -1 and len(sentence) > 0:
#         print("Not found")
#     else:
#         print(sentence[:substr_index])
#
# We are learn
# Not found
# Let's f
#
# >>> sentence_list = [sentence for sentence in sentence_list if len(sentence) > 0] #this is called a "list comprehension"
# >>> sentence_list
# ['We are learning about strings', 'The weather is great today', "Let's finish up and go have lunch outside"]
# >>> [num for num in range(1,10)]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# >>> [num*5 for num in range(1,10)]
# [5, 10, 15, 20, 25, 30, 35, 40, 45]
# >>> "  hi there mate!  \n".strip('e \n!')
# 'hi there mat'
# >>> "  hi there mate!  \n".strip('e')
# '  hi there mate!  \n'
# >>> >>> "  hi there mate!  \n".strip('\ne! ') #Does character order matter?
#   File "<pyshell>", line 1
#     >>> "  hi there mate!  \n".strip('\ne! ') #Does character order matter
#      ^
# SyntaxError: invalid syntax
# >>> "  hi there mate!  \n".strip('\ne! ') #Does character order matter?
# >>> result = "  hi there mate!  \n".strip('\ne! ') #Does character order matter?
# >>> print(result)
# hi there mat
# >>> result = "  hi there mate!  \n".strip('ne\! ') #special character sequences do matter though
# >>> result
# 'hi there mate!  \n'
# >>> #what the heck is \!
# >>> "\!"
# '\\!'
# >>> '\!'
# '\\!'
# >>> strings = "  hi there mate!  \n".split()
# >>> for word in strings:
#     print(word.strip("\ne! "))
#
# hi
# ther
# mat
#
# ```
