# %% [markdown]
# # Class Notes
#
# Below is a copy of live-coded notes from class Tuesday 2/26. You can study what we worked on, recreate your own version, or copy them directly into Thonny to re-run the code.

# %% [markdown]
# **midtermdemo.py**

# %%
"""
Ask the user to input a midterm 1 grade and a
midterm 2 grade, then print the higher of the two
"""

midterm1 = int(input("What is your midterm 1 grade?"))
midterm2 = int(input("What is your midterm 2 grade?"))

def compare_str_int(num, text):
    return num

print("Your higher grade is:", max(midterm1, midterm2))

# %% [markdown]
# **parkingspotdemo.py**

# %%
last_name = "Montoya"
spot_number = 45
def parking_pass(name, spot):
    if type(name) == type("") and type(spot) == type(25):
        return f"Parking pass for {name}. Parking is reserved in spot number {spot}"
    else:
        return "Sorry, one of your variables was the wrong type"

# %% [markdown]
# **Code run in the Python Shell**
# *note: Some of this code relies on the* `*.py` *files listed above*
#
# ```Python
# #Python 3.7.2 (bundled)
# >>> print("The largest number in the list is: ", max(1, 5, 6, 9, 3))
# The largest number in the list is:  9
# >>> %Run midtermDemo.py
# Traceback (most recent call last):
#   File "C:\Users\DaveTheDev\Dev\UD\midtermDemo.py", line 9
#     print max(midterm1, midterm2)
#             ^
# SyntaxError: invalid syntax
# >>> %Run midtermDemo.py
# What is your midterm 1 grade?45
# What is your midterm 2 grade?68
# 68
# >>> %Run midtermDemo.py
# What is your midterm 1 grade?68
# What is your midterm 2 grade?75
# Your higher grade is: 75
# >>> midterm1
# '68'
# >>> type(midterm1)
# <class 'str'>
# >>> help(max)
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.
#
# >>> max([1,3,5,3])
# 5
# >>> max("Cats", "Dogs")
# 'Dogs'
# >>> max("Cats", "dogs")
# 'dogs'
# >>> max("cats", "DOGS")
# 'cats'
# >>> max(True, False)
# True
# >>> max(False, True)
# True
# >>> max("95", "bad")
# 'bad'
# >>> %Run midtermDemo.py
# What is your midterm 1 grade?55
# What is your midterm 2 grade?perfect
# Traceback (most recent call last):
#   File "C:\Users\DaveTheDev\Dev\UD\midtermDemo.py", line 7, in <module>
#     midterm2 = int(input("What is your midterm 2 grade?"))
# ValueError: invalid literal for int() with base 10: 'perfect'
# >>> max("95", bad)
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# NameError: name 'bad' is not defined
# >>> max(95, "bad")
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# TypeError: '>' not supported between instances of 'str' and 'int'
# >>> %Run midtermDemo.py
# What is your midterm 1 grade?1
# What is your midterm 2 grade?1
# Your higher grade is: 1
# >>> help(max)
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.
#
# >>> max(95, "bad", key=compare_str_int)
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# TypeError: compare_str_int() missing 1 required positional argument: 'text'
# >>> %Run parkingspotdemo.py
# >>> parking_pass(last_name, spot_number)
# 'Parking pass for Montoya. Parking is reserved in spot number 45'
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>> parking_pass(spot_number, last_name)
# 'Sorry, one of your variables was the wrong type'
# >>> parking_pass(last_name, spot_number)
# 'Parking pass for Montoya. Parking is reserved in spot number 45'
# >>> type(last_name)
# <class 'str'>
# >>> type(spot_number)
# <class 'int'>
# >>> parking_pass(spot_number, last_name)
# 'Sorry, one of your variables was the wrong type'
# >>> parking_pass("Ginzberg", 312)
# 'Parking pass for Ginzberg. Parking is reserved in spot number 312'
# >>> print_return_value = print("I don't return anything")
# I don't return anything
# >>> print_return_value
# >>> type(print_return_value)
# <class 'NoneType'>
# >>> print(print_return_value)
# None
# >>> print(print_return_value)
# ```
