# %% [markdown]
# # Class Notes
#
# Below is a copy of live-coded notes from class Tuesday April 9. You can study what we worked on, recreate your own version, or copy them directly into Thonny to re-run the code.

# %% [markdown]
# **Code run in the Python Shell**
# *note: Some of this code relies on the* `*.py` *files listed above*
#
# ```Python
# Python 3.7.2 (bundled)
# >>> "La" * 3
# 'LaLaLa'
# >>> "La" + "La" + "La"
# 'LaLaLa'
# >>> "La" * 23
# 'LaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLaLa'
# >>> #How can we create a multi-line string? Can't we just type [enter] to get a multi-line string?
# >>> "this string is multiple
#   File "<pyshell>", line 1
#     "this string is multiple
#                            ^
# SyntaxError: EOL while scanning string literal
# >>> lines"
#   File "<pyshell>", line 1
#     lines"
#          ^
# SyntaxError: EOL while scanning string literal
# >>> #Apparently not -- Python doesn't like that, but there *is* a way to add newlines to a string:
# >>> "this string is multiple\nlines"
# 'this string is multiple\nlines'
# >>> print("this string is multiple\nlines")
# this string is multiple
# lines
# >>> print("Each\n\tLine\n\t\tIs\n\t\t\tIndented")
# Each
#     Line
#         Is
#             Indented
# >>> #That code's a little tough to read though; here's a slightly better way:
# >>> better_string = '''
# Each
#     Line
#         Is
#             Indented
#             '''
# >>> print(better_string)
#
# Each
#     Line
#         Is
#             Indented
#
# >>> "University of Delaware".startswith("Delaware")
# False
# >>> "University of Delaware".find(" ")
# 10
# >>> "University of Delaware".find(" ", 10)
# 10
# >>> "University of Delaware".find(" ", 11)
# 13
# >>> "University of Delaware".startswith("Delaware", 13)
# False
# >>> "University of Delaware".startswith("Delaware", 14)
# True
# >>> "University of Delaware".startswith("Delaware", 14, -3)
# False
# >>> "University of Delaware".startswith("Del", 14, -3)
# True
# >>> "University of Delaware"[14,-3]
# Traceback (most recent call last):
#   File "<pyshell>", line 1, in <module>
# TypeError: string indices must be integers
# >>> univ_str = "University of Delaware"
# >>> univ_str[14:len(univ_str)-3)
#   File "<pyshell>", line 1
#     univ_str[14:len(univ_str)-3)
#                                ^
# SyntaxError: invalid syntax
# >>> univ_str[14:len(univ_str)-3]
# 'Delaw'
# >>> univ_str.upper()
# 'UNIVERSITY OF DELAWARE'
# >>> univ_str.lower
# <built-in method lower of str object at 0x02A37440>
# >>> univ_str.lower()
# 'university of delaware'
# >>> univ_str
# 'University of Delaware'
# >>> all_caps_UD = univ_str.upper()
# >>> univ_str
# 'University of Delaware'
# >>> all_caps_UD
# 'UNIVERSITY OF DELAWARE'
# >>> univ_str.endswith("are")
# True
# >>> all_caps_UD.endswith("are")
# False
# >>> words = all_caps_UD.split()
# >>> words
# ['UNIVERSITY', 'OF', 'DELAWARE']
# >>> words = all_caps_UD.split(" ")
# >>> words
# ['UNIVERSITY', 'OF', 'DELAWARE']
# >>> len(words)
# 3
# >>> "My name is {}".format("David")
# 'My name is David'
# >>> my_name = "Inigo Montoya"
# >>> "My name is {}".format(my_name)
# 'My name is Inigo Montoya'
# >>> f"My name is {my_name}"
# 'My name is Inigo Montoya'
# >>> name_and_message = "My name is {}, {}"
# >>> message = "prepare to die"
# >>> name_and_message.format(message, my_name)
# 'My name is prepare to die, Inigo Montoya'
# >>> "My name is {my_name}, {message}"
# 'My name is {my_name}, {message}'
# >>> f"My name is {my_name}, {message}" #forgot the 'f' at the beginning!
# 'My name is Inigo Montoya, prepare to die'
# >>> all_caps_UD
# 'UNIVERSITY OF DELAWARE'
# >>> # how does str.split() work?
# >>> # how does str.strip() work?
# >>> all_caps_UD.strip()
# 'UNIVERSITY OF DELAWARE'
# >>> all_caps_UD.strip("AEIOUY")
# 'NIVERSITY OF DELAWAR'
# >>> user_input = input("Where are you?")
# Where are you?                         Newark.
# >>> user_input
# '                         Newark.        '
# >>> len(user_input)
# 40
# >>> cleaned_user_input = user_input.strip()
# >>> cleaned_user_input
# 'Newark.'
# >>> len(cleaned_user_input)
# 7
# >>> cleaned_user_input = user_input.strip(" ,.;\"\'") #let's get rid of punctuation
# >>> cleaned_user_input
# 'Newark'
# >>> user_input = input("Where are you?")
# Where are you?"Newark"
# >>> cleaned_user_input = user_input.strip(" ,.;\"\'") #let's get rid of punctuation
# >>> cleaned_user_input
# 'Newark'
# >>> "aestrophyzzixyyy".strip("AEIOUY") #some silly example with multiple vowels
# 'aestrophyzzixyyy'
# >>> "aestrophyzzixyyy".upper().strip("AEIOUY")
# 'STROPHYZZIX'
# >>> "aestrophyzzixyyy".upper().strip("AEIOUY").lower()
# 'strophyzzix'
# >>> "aestrophyzzixyyy".strip("AEIOUY".lower())
# 'strophyzzix'
# >>> "aestrophyzzixyyy".strip("aeiouy")
# 'strophyzzix'
# >>> #each of those did the same thing in a slightly different way
# >>> ord("!")
# 33
# >>> ord("A")
# 65
# >>> chr(34)
# '"'
# >>>
#
#
# ```
